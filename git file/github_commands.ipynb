# %% [markdown]
# |GIT commands:
# --------------
# git init  -> initialize git
# git add .  --> add all the files for tracking
# git commit -m "very first git commit"
# git config --global user.email "you@example.com"
# git config --global user.name "Monalsingh"
# git commit -m "very first git commit"
# git branch -M main  # while installing, we mentioned to use 'main'
# git remote add origin https://github.com/Monalsingh/dummy1.git
# git push -u origin main
# git branch branch_name
# git branch -b branch_name
# git checkout branch
# git add . && git commit -m "message"
# git status
# git pull origin main
# git pull
# git add "file_name"
# git clone remote_url

# %% [markdown]
# |GIT authentication commands:
# -----------------------------
# rm -rf ~/.ssh/*
# ssh-keygen -t ed25519 -C "your_email@example.com"
# cat ~/.ssh/id_ed25519.pub
# Go to: https://github.com/settings/ssh/new
# Title: (e.g., "My Laptop SSH Key")
# Key: Paste your copied public key
# Click "Add SSH key"
# ssh -T git@github.com

# %% [markdown]
# |T0 remove the user name and mail:
# ---------------------------------
# git config --global --unset user.name
# git config --global --unset user.email
# ..it will automatically remove the user namer and mail
# to check: git config --list..if the use name and user mail is not appearing than it was successfully deleted
#
# |To add new one:
# ----------------
# git config --global user.name "Your New Name"
# git config --global user.email "yournewemail@example.com"

# %% [markdown]
# ## From GitHub:
# |Create a new repository on the command line
# ---------------------------------------------------------
# echo "# project01" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch
# git branch -M main
# git remote add origin https://github.com/im-krishh/project01.git
# git push -u origin main
#
# |Push an existing repository from the command line:
# ---------------------------------------------------
# git remote add origin https://github.com/im-krishh/project01.git
# git branch -M main
# git push -u origin main

# %% [markdown]
# Using GIT to:
#
# 1. Versioning tool
# 2. Collaborate with others
# 3. Revert back changes
#
# Using GITHUB to:
#
#  1. Stores GIT respositories online
#  2. Share code in online(public&private)
#  3. Pull requests, branches

# %% [markdown]
# |Open GitHub:
# ------------
# Signed in through mail:
# ie. hii.krishh@gmail.com[username: im-krishh]
# Open Repositories..click new..create repository with name
# Open terminal..select GitBash
# ls: folder
# pwd: current projct directory
